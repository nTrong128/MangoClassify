# %%
# %env TF_CPP_MIN_LOG_LEVEL=3

import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory # type: ignore
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
train_dataset_directory = "../raw1/"
test_dataset_directorry = "../raw_to_test1/"

img_size = (150, 150)
batch_size = 32
validation_split = 0.1

# %%
train_dataset = image_dataset_from_directory(
    train_dataset_directory,
    labels='inferred',  # inferred from the directory structure
    label_mode='int', # encoded as integer
    batch_size=batch_size, 
    image_size=img_size, 
    shuffle=True,
    seed=42,
    validation_split=validation_split,
    subset="training"
)

validation_dataset = image_dataset_from_directory(
    train_dataset_directory,
    labels='inferred', 
    label_mode='int',
    batch_size=batch_size,
    image_size=img_size,
    shuffle=True,
    seed=42,
    validation_split=validation_split,
    subset="validation"
)

test_dataset = image_dataset_from_directory(
    test_dataset_directorry,
    labels='inferred',
    label_mode='int',
    batch_size=batch_size,
    image_size=img_size,
    shuffle=True,
    seed=42
)
# Out:
# Found 1586 files belonging to 3 classes.
# Using 1428 files for training.
# Found 1586 files belonging to 3 classes.
# Using 158 files for validation.
# Found 461 files belonging to 3 classes.

# %%
import matplotlib.pyplot as plt

def display_images(dataset, num_images=9):
    class_names = dataset.class_names 
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1): 
        for i in range(num_images):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[int(labels[i])])
            plt.axis("off")
    plt.show()

display_images(train_dataset, num_images=3)
display_images(validation_dataset, num_images=3)
display_images(test_dataset, num_images=3)

# %%
print(f'Number of Train batches: {len(train_dataset)}')
print(f'Number of  Validation batches: {len(validation_dataset)}')
print(f'Number of  Test batches: {len(test_dataset)}')
# Out:
# Number of Train batches: 45
# Number of  Validation batches: 5
# Number of  Test batches: 15

# %%
input_shape = img_size + (3,)
class_numbers = len(train_dataset.class_names)
print(f'Input shape: {input_shape}')
print(f'Class number: {class_numbers}')
# Out:
# Input shape: (150, 150, 3)
# Class number: 3

# %%
from tensorflow.keras import layers, models   # type: ignore

model = models.Sequential(name="trained_5")
model.add(layers.Input(shape=input_shape))
model.add(layers.Rescaling(1./255))  # normalize the pixel values to be between 0 and 1 (devided by 255) for better performance

model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Dropout(0.5))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Dropout(0.5))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())

model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(class_numbers, activation='softmax'))

# %%
learning_rate = 0.0001
print(f'Learning rate: {learning_rate}')
# Out:
# Learning rate: 0.0001

# %%
from tensorflow.keras import optimizers  # type: ignore

optimizer = optimizers.Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "trained_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18496)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     1,183,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,240,323 (4.73 MB)
#  Trainable params: 1,240,323 (4.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=5,
    restore_best_weights=True
)

# %%
# Run a few dummy batches to warm up the GPU
warmup_data = next(iter(train_dataset))
_ = model.predict(warmup_data[0])  # Use predict to trigger the GPU
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# E0000 00:00:1727554816.060763   11263 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554816.349936   11263 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3827 - loss: 1.1497
# E0000 00:00:1727554823.939257   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554824.181659   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554824.311831   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554824.580556   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554824.853758   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727554825.258860   11261 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 19s 253ms/step - accuracy: 0.3848 - loss: 1.1470 - val_accuracy: 0.5127 - val_loss: 1.0846
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.5215 - loss: 0.9889 - val_accuracy: 0.4810 - val_loss: 1.0727
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.5156 - loss: 0.9664 - val_accuracy: 0.5886 - val_loss: 1.0535
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.5456 - loss: 0.9043 - val_accuracy: 0.5886 - val_loss: 1.0269
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.5627 - loss: 0.9090 - val_accuracy: 0.6266 - val_loss: 1.0193
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.5765 - loss: 0.8761 - val_accuracy: 0.6646 - val_loss: 0.9863
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6294 - loss: 0.8338 - val_accuracy: 0.7722 - val_loss: 0.9806
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.6493 - loss: 0.7597 - val_accuracy: 0.7911 - val_loss: 0.9437
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.6961 - loss: 0.7022 - val_accuracy: 0.8101 - val_loss: 0.9019
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7247 - loss: 0.6569 - val_accuracy: 0.8291 - val_loss: 0.8667
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7581 - loss: 0.6059 - val_accuracy: 0.8418 - val_loss: 0.7908
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7644 - loss: 0.5484 - val_accuracy: 0.8544 - val_loss: 0.7184
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.7881 - loss: 0.4987 - val_accuracy: 0.8797 - val_loss: 0.6426
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8114 - loss: 0.4624 - val_accuracy: 0.8861 - val_loss: 0.5943
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8302 - loss: 0.4011 - val_accuracy: 0.8924 - val_loss: 0.5271
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8377 - loss: 0.3704 - val_accuracy: 0.8987 - val_loss: 0.4921
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8553 - loss: 0.3490 - val_accuracy: 0.8987 - val_loss: 0.5015
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8647 - loss: 0.3312 - val_accuracy: 0.8987 - val_loss: 0.4559
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8776 - loss: 0.2944 - val_accuracy: 0.8734 - val_loss: 0.4171
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8743 - loss: 0.3060 - val_accuracy: 0.9241 - val_loss: 0.3854
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8794 - loss: 0.2974 - val_accuracy: 0.9177 - val_loss: 0.3827
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8890 - loss: 0.2812 - val_accuracy: 0.9241 - val_loss: 0.3492
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8977 - loss: 0.2765 - val_accuracy: 0.7848 - val_loss: 0.4413
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8782 - loss: 0.3244 - val_accuracy: 0.8544 - val_loss: 0.3861
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9073 - loss: 0.2479 - val_accuracy: 0.9114 - val_loss: 0.3257
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9128 - loss: 0.2162 - val_accuracy: 0.9430 - val_loss: 0.2965
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9013 - loss: 0.2542 - val_accuracy: 0.8734 - val_loss: 0.3337
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9055 - loss: 0.2423 - val_accuracy: 0.9177 - val_loss: 0.2796
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9121 - loss: 0.2012 - val_accuracy: 0.9430 - val_loss: 0.2579
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9241 - loss: 0.1915 - val_accuracy: 0.9494 - val_loss: 0.2670
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9486 - loss: 0.1620 - val_accuracy: 0.9051 - val_loss: 0.2751
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9323 - loss: 0.1957 - val_accuracy: 0.9620 - val_loss: 0.2335
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9319 - loss: 0.1651 - val_accuracy: 0.9304 - val_loss: 0.2445
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9264 - loss: 0.1788 - val_accuracy: 0.9494 - val_loss: 0.2291
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9419 - loss: 0.1666 - val_accuracy: 0.9430 - val_loss: 0.2058
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9354 - loss: 0.1576 - val_accuracy: 0.9367 - val_loss: 0.2267
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9295 - loss: 0.1993 - val_accuracy: 0.9620 - val_loss: 0.1902
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9491 - loss: 0.1347 - val_accuracy: 0.9810 - val_loss: 0.1772
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9525 - loss: 0.1231 - val_accuracy: 0.9430 - val_loss: 0.1803
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9512 - loss: 0.1393 - val_accuracy: 0.9241 - val_loss: 0.1967
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9299 - loss: 0.1655 - val_accuracy: 0.9810 - val_loss: 0.1546
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9381 - loss: 0.1407 - val_accuracy: 0.9620 - val_loss: 0.1644
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9474 - loss: 0.1460 - val_accuracy: 0.9747 - val_loss: 0.1327
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9509 - loss: 0.1431 - val_accuracy: 0.9810 - val_loss: 0.1398
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9516 - loss: 0.1256 - val_accuracy: 0.9620 - val_loss: 0.1586
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9389 - loss: 0.1278 - val_accuracy: 0.9747 - val_loss: 0.1466
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9602 - loss: 0.0995 - val_accuracy: 0.9810 - val_loss: 0.1461
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9511 - loss: 0.1418 - val_accuracy: 0.9810 - val_loss: 0.1178
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9454 - loss: 0.1258 - val_accuracy: 0.9747 - val_loss: 0.1107
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9547 - loss: 0.1199 - val_accuracy: 0.9873 - val_loss: 0.0984

# %%
model_filename = f'./output/mango_classifier_trained5.keras'

model.save(model_filename)

print(f'Model saved to {model_filename}')
# Out:
# Model saved to ./output/mango_classifier_trained5.keras

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9408 - loss: 0.1700
# Test accuracy: 0.9436

# %%
import matplotlib.pyplot as plt

# Plotting accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

class_labels = ['ripe', 'rotten', 'unripe']

true_labels = []
predicted_labels = []

for images, labels in test_dataset:

    preds = model.predict(images)
    predicted_labels.extend(np.argmax(preds, axis=1)) 
    true_labels.extend(labels.numpy())
cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step

# %%
new_model = tf.keras.models.load_model('./output/mango_classifier_trained5.keras')

# %%
class_labels = ['ripe', 'rotten', 'unripe']

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


new_model = tf.keras.models.load_model('./output/mango_classifier_trained5.keras')
class_labels = ['ripe', 'rotten', 'unripe']


def display_random_images_grid(dataset, model, class_labels, grid_size=3):
    plt.figure(figsize=(10, 10))  # Adjust figure size based on grid
    for images, labels in dataset.take(1):  # Take one batch of data
        for i in range(grid_size * grid_size):  # Create a grid of grid_size x grid_size images
            random_index = random.randint(0, len(images) - 1)  # Randomly pick an image

            random_image = images[random_index]
            true_label = labels[random_index].numpy()

            # Make a prediction
            prediction = model.predict(np.expand_dims(random_image, axis=0)) 
            predicted_label = np.argmax(prediction, axis=1)[0]

            # Plot each image in the grid
            ax = plt.subplot(grid_size, grid_size, i + 1)  
            plt.imshow(random_image.numpy().astype("uint8"))
            plt.title(f"Thực tế: {class_labels[true_label]}\nDự đoán: {class_labels[predicted_label]}")
            plt.axis("off")  # Hide the axis

    plt.show()

display_random_images_grid(test_dataset, new_model, class_labels, grid_size=3)

# %%
display_random_images_grid(test_dataset, model, class_labels, grid_size=3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
